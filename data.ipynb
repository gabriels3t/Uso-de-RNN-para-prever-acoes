# %%
import yfinance as yf
import numpy as np

# %% [markdown]
# # Pegando dados e dividindo entre feature e target

# %%
# Definir os ativos e o período
ativos4 = ['SUZB3.SA', 'EMBR3.SA', 'PETR4.SA', 'EGIE3.SA', 'BBSE3.SA', 'ITSA4.SA', 'ABEV3.SA', 'WEGE3.SA', 'FLRY3.SA', 'TAEE4.SA', 'USDBRL=X','^BVSP']
data_inicial = '2017-01-01'
#data_inicial = '2024-01-01'
data_final = '2025-12-30'

# Obtendo os dados diretamente com o yfinance
tabela_cotacoes = yf.download(ativos4, start=data_inicial, end=data_final)

# Removendo os NA
cotacao_sem_nulos = tabela_cotacoes.dropna()

cotacao_sem_nulos.head()
# Out:
# [*********************100%***********************]  12 of 12 completed
# Price           Close                                                        \
# Ticker       ABEV3.SA   BBSE3.SA   EGIE3.SA   EMBR3.SA   FLRY3.SA  ITSA4.SA
# Date
# 2017-05-10  14.118643  16.562654  15.847738  15.486095  20.420809  4.513855
# 2017-05-11  14.368791  16.589912  15.732330  15.545163  20.508602  4.589834
# 2017-05-12  14.486503  16.987894  15.893905  15.564854  20.578836  4.603239
# 2017-05-15  14.523289  16.900663  16.009310  15.722374  20.498070  4.603239
# 2017-05-16  14.582150  17.249582  16.097015  15.545163  20.469975  4.589834
#
# Price                                               ...     Volume             \
# Ticker      PETR4.SA   SUZB3.SA  TAEE4.SA USDBRL=X  ...   EGIE3.SA   EMBR3.SA
# Date                                                ...
# 2017-05-10  4.374013  17.149134  5.970147   3.1868  ...  1278375.0  3023300.0
# ...

# %%
cotacao_feature = cotacao_sem_nulos  # Features
cotacao_target = cotacao_sem_nulos['Close']  # Target

# %%
cotacao_target.head()
# Out:
# Ticker       ABEV3.SA   BBSE3.SA   EGIE3.SA   EMBR3.SA   FLRY3.SA  ITSA4.SA  \
# Date
# 2017-05-10  14.118643  16.562654  15.847738  15.486095  20.420809  4.513855
# 2017-05-11  14.368791  16.589912  15.732330  15.545163  20.508602  4.589834
# 2017-05-12  14.486503  16.987894  15.893905  15.564854  20.578836  4.603239
# 2017-05-15  14.523289  16.900663  16.009310  15.722374  20.498070  4.603239
# 2017-05-16  14.582150  17.249582  16.097015  15.545163  20.469975  4.589834
#
# Ticker      PETR4.SA   SUZB3.SA  TAEE4.SA  USDBRL=X  WEGE3.SA    ^BVSP
# Date
# 2017-05-10  4.374013  17.149134  5.970147    3.1868  6.620127  67350.0
# 2017-05-11  4.400740  17.149134  5.970147    3.1657  6.736629  67538.0
# 2017-05-12  4.587814  17.149134  5.970147    3.1390  6.859986  68222.0
# 2017-05-15  4.656113  17.149134  5.970147    3.1777  6.997048  68474.0
# 2017-05-16  4.662051  17.149134  5.970147    3.1082  6.681805  68684.0

# %% [markdown]
# # Agrupando features em 10 dias

# %%
# Defina o tamanho da janela
window_size = 10

# Crie as janelas 
#cotacao_feature_grouped = [cotacao_feature.iloc[i:i + window_size] for i in range(0, len(cotacao_feature) - window_size)]
cotacao_feature_grouped = [cotacao_feature.iloc[i:i + window_size] for i in range(0, len(cotacao_feature), window_size)]

# Verifique o número de janelas criadas e o tamanho das janelas
print(f"Quantidade de janelas criadas: {len(cotacao_feature_grouped)}")
print(f"Formato da primeira janela: {cotacao_feature_grouped[0].shape}")  # Esperado: (10, 60)

cotacao_feature_grouped[0]
# Out:
# Quantidade de janelas criadas: 190
# 2024-12-06  13.477178  35.419998  37.682224  57.320000  12.876739   9.213663
# 2024-12-20  12.230000  36.529999  36.820000  54.959999  12.660000   8.920000
#
# ...

# %% [markdown]
# ## Utilizando o indice MACD

# %%
# Função para calcular MACD e Signal para os ativos em cada janela
def calcular_macd_em_janelas(cotacao_feature_grouped, ativos):
    # Cria uma lista para armazenar as novas janelas com MACD e Signal
    cotacao_feature_with_macd = []

    # Iterar sobre cada janela
    for janela in cotacao_feature_grouped:
        # Iterando sobre cada ativo para calcular o MACD e a linha de sinal
        for ativo in ativos:
            # Seleciona os dados de fechamento do ativo na janela e remove valores nulos
            cotacao = janela['Close'][ativo].dropna()

            # Calculando as EMAs de 12 e 26 períodos
            EMA12 = cotacao.ewm(span=12, adjust=False).mean()
            EMA26 = cotacao.ewm(span=26, adjust=False).mean()

            # Calculando o MACD (diferença entre EMA12 e EMA26)
            MACD = EMA12 - EMA26
            janela[('MACD', ativo)] = MACD  # Adiciona o MACD na janela

            # Calculando a linha de sinal (EMA de 9 períodos do MACD)
            Signal = MACD.ewm(span=9, adjust=False).mean()
            janela[('Signal', ativo)] = Signal  # Adiciona a linha de sinal na janela

        # Adiciona a janela modificada à lista
        cotacao_feature_with_macd.append(janela)

    return cotacao_feature_with_macd

# %%
cotacao_feature_with_macd = calcular_macd_em_janelas(cotacao_feature_grouped, ativos4)
# Out:
# /tmp/ipykernel_28033/2354637659.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   janela[('MACD', ativo)] = MACD  # Adiciona o MACD na janela
# /tmp/ipykernel_28033/2354637659.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   janela[('Signal', ativo)] = Signal  # Adiciona a linha de sinal na janela
# /tmp/ipykernel_28033/2354637659.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
cotacao_feature_with_macd[-1]['Signal']
# Out:
# Ticker      SUZB3.SA  EMBR3.SA  PETR4.SA  EGIE3.SA  BBSE3.SA  ITSA4.SA  \
# Date
# 2024-12-20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2024-12-23  0.025846  0.009413  0.000154 -0.019145 -0.000638 -0.001915
# 2024-12-26  0.077647  0.035220  0.004196 -0.049881 -0.001960 -0.003329
# 2024-12-27  0.137238  0.071305  0.008699 -0.096209 -0.006669 -0.005465
# 2024-12-30  0.201307  0.109544  0.021691 -0.140886 -0.014834 -0.007929
# 2025-01-02  0.277449  0.170491  0.050600 -0.184258 -0.022469 -0.012525
#
# Ticker      ABEV3.SA  WEGE3.SA  FLRY3.SA  TAEE4.SA  USDBRL=X       ^BVSP
# Date
# 2024-12-20  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 2024-12-23 -0.000160 -0.019468 -0.004627 -0.005584 -0.001075  -21.299145
# 2024-12-26 -0.001687 -0.043373 -0.015251 -0.012767  0.007576  -49.821277
# 2024-12-27 -0.005104 -0.084341 -0.027766 -0.021026  0.012537  -94.169030
# 2024-12-30 -0.014780 -0.148184 -0.043459 -0.029317  0.015617 -145.673201
# ...

# %% [markdown]
# # Passando os dados para array

# %%
# Converta todas as janelas de DataFrame para arrays NumPy
X =[window.values for window in cotacao_feature_grouped]
X = np.array(X[:-1])

# %%
Y = cotacao_target_intervalo.to_numpy()

# %%
print(f"Shape das features de treino: {X.shape}")
print(f"Shape do target: {Y.shape}")
# Out:
# Shape das features de treino: (189, 10, 84)
# Shape do target: (189, 10)

# %% [markdown]
# # Salvando features e target

# %%
np.save('data/feature.npy', X)
np.save('data/target.npy',Y)
